# %%
import pandas as pd
from numpy import nan

# %%
diabet= pd.read_csv('./pima-indians-diabetes.csv', header=None)

# %%
diabet.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
# Replace 0 values with NaN
diabet[[1,2,3,4,5]] = diabet[[1,2,3,4,5]].replace(0, nan)

# %%
diabet.head()
# Out:
#    0      1     2     3      4     5      6   7  8
# 0  6  148.0  72.0  35.0    NaN  33.6  0.627  50  1
# 1  1   85.0  66.0  29.0    NaN  26.6  0.351  31  0
# 2  8  183.0  64.0   NaN    NaN  23.3  0.672  32  1
# 3  1   89.0  66.0  23.0   94.0  28.1  0.167  21  0
# 4  0  137.0  40.0  35.0  168.0  43.1  2.288  33  1

# %%
diabet[4].value_counts(dropna=False)
# Out:
# NaN      374
# 105.0     11
# 130.0      9
# 140.0      9
# 120.0      8
#         ...
# 32.0       1
# 271.0      1
# 61.0       1
# 360.0      1
# 485.0      1
# Name: 4, Length: 186, dtype: int64

# %%
diabet[2:5]
# Out:
#    0      1     2     3      4     5      6   7  8
# 2  8  183.0  64.0   NaN    NaN  23.3  0.672  32  1
# 3  1   89.0  66.0  23.0   94.0  28.1  0.167  21  0
# 4  0  137.0  40.0  35.0  168.0  43.1  2.288  33  1

# %%
diabet.loc[2:5]
# Out:
#    0      1     2     3      4     5      6   7  8
# 2  8  183.0  64.0   NaN    NaN  23.3  0.672  32  1
# 3  1   89.0  66.0  23.0   94.0  28.1  0.167  21  0
# 4  0  137.0  40.0  35.0  168.0  43.1  2.288  33  1
# 5  5  116.0  74.0   NaN    NaN  25.6  0.201  30  0

# %%
diabet.loc[2:5,1:3]
# Out:
#        1     2     3
# 2  183.0  64.0   NaN
# 3   89.0  66.0  23.0
# 4  137.0  40.0  35.0
# 5  116.0  74.0   NaN

# %%
df = pd.read_csv('./titanic.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Cabin'].value_counts(dropna=False)
# Out:
# NaN            687
# B96 B98          4
# C23 C25 C27      4
# G6               4
# E101             3
#               ...
# D15              1
# D19              1
# C110             1
# A7               1
# B50              1
# Name: Cabin, Length: 148, dtype: int64

# %% [markdown]
# # Olympic Medals

# %%
oo = pd.read_csv('./olympics.csv', skiprows=4)

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
oo[['City','Edition']]
# Out:
#           City  Edition
# 0       Athens     1896
# 1       Athens     1896
# 2       Athens     1896
# 3       Athens     1896
# 4       Athens     1896
# ...        ...      ...
# 29211  Beijing     2008
# 29212  Beijing     2008
# 29213  Beijing     2008
# 29214  Beijing     2008
# 29215  Beijing     2008
#
# [29216 rows x 2 columns]

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1956     885
# 1912     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo.Gender.value_counts(ascending=True)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.sort_values(by=["Edition","Athlete"])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# # Boolean Indexing

# %%
oo.Medal == 'Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
oo[oo.Medal == 'Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %% [markdown]
# # String Handeling

# %%
oo.Athlete.str.contains('Florence')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214    False
# 29215    False
# Name: Athlete, Length: 29216, dtype: bool

# %%
oo[oo.Athlete.str.contains('Florence')].head(3)
# Out:
#         City  Edition     Sport      Discipline           Athlete  NOC Gender  \
# 1843  London     1908   Skating  Figure skating   SYERS, Florence  GBR  Women
# 1848  London     1908   Skating  Figure skating   SYERS, Florence  GBR  Women
# 4173   Paris     1924  Aquatics        Swimming  BARKER, Florence  GBR  Women
#
#                        Event Event_gender   Medal
# 1843              individual            W    Gold
# 1848                   pairs            X  Bronze
# 4173  4x100m freestyle relay            W  Silver

# %% [markdown]
# # Challenge
#
# ## In which events did jesse Owens win a medal?

# %%
oo[oo.Athlete.str.contains('owens, Jesse',case= False)]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
oo[oo.Athlete.str.contains('OWENS, Jesse')]['Event']
# Out:
# 6427            100m
# 6439            200m
# 6456    4x100m relay
# 6523       long jump
# Name: Event, dtype: object

# %% [markdown]
# ## Which country has won the most men's gold medals in single badminton over the years?
#
# #### sort the results alphabetically by the players names.

# %%
oo[(oo.Medal =='Gold')& (oo.Sport=='Badminton') &(oo.Gender=='Men')]['NOC'].value_counts()
# Out:
# INA    8
# KOR    6
# CHN    4
# DEN    1
# Name: NOC, dtype: int64

# %%
oo[(oo.Medal =='Gold')& (oo.Sport=='Badminton') &(oo.Gender=='Men')].sort_values(by=['Athlete']).head(5)
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 23701    Men  doubles            M  Gold
# 25718    Men  doubles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold

# %% [markdown]
# ## Which three countries have won the most medals in recent years (from 1984 to 2008)?

# %%
oo[(oo.Edition <=2008) & (oo.Edition>=1984)]
# Out:
#               City  Edition      Sport       Discipline  \
# 16592  Los Angeles     1984   Aquatics           Diving
# 16593  Los Angeles     1984   Aquatics           Diving
# 16594  Los Angeles     1984   Aquatics           Diving
# 16595  Los Angeles     1984   Aquatics           Diving
# 16596  Los Angeles     1984   Aquatics           Diving
# ...            ...      ...        ...              ...
# 29211      Beijing     2008  Wrestling  Wrestling Gre-R
# 29212      Beijing     2008  Wrestling  Wrestling Gre-R
# 29213      Beijing     2008  Wrestling  Wrestling Gre-R
# 29214      Beijing     2008  Wrestling  Wrestling Gre-R
# 29215      Beijing     2008  Wrestling  Wrestling Gre-R
#
#                            Athlete  NOC Gender         Event Event_gender  \
# 16592               LI, Kong-Zheng  CHN    Men  10m platform            M
# 16593            LOUGANIS, Gregory  USA    Men  10m platform            M
# ...

# %%
oo[(oo.Edition <=2008) & (oo.Edition>=1984)].NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %% [markdown]
# ## Display the male gold medal winners for the 100m track and field sprint event over the years

# %%
oo[(oo.Medal =='Gold') & (oo.Gender =='Men') & (oo.Event == '100m')].sort_values(by=['Edition'],ascending=False)[['City','Edition','Athlete','NOC']].head(5)
# Out:
#             City  Edition            Athlete  NOC
# 27552    Beijing     2008        BOLT, Usain  JAM
# 25539     Athens     2004     GATLIN, Justin  USA
# 23521     Sydney     2000    GREENE, Maurice  USA
# 21598    Atlanta     1996    BAILEY, Donovan  CAN
# 19859  Barcelona     1992  CHRISTIE, Linford  GBR

# %% [markdown]
# ## Basic Plotting

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fo = oo[oo.Edition == 1896]
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fo.Sport.value_counts()
# Out:
# Gymnastics       45
# Athletics        37
# Cycling          16
# Shooting         15
# Aquatics         11
# Tennis           10
# Fencing           8
# Weightlifting     6
# Wrestling         3
# Name: Sport, dtype: int64

# %%
fo.Sport.value_counts().plot(kind='bar');

# %%
fo.plot(); # be carefull about this kind of use!

# %%
fo.Gender.value_counts().plot(kind= 'pie');

# %%
fo.Sport.value_counts().plot(kind='bar', figsize=(10,5));

# %%
import seaborn as sns

# %%
sns.countplot(x="Medal",data=oo);

# %%
sns.countplot(x="Medal",data=oo, hue='Gender');

# %% [markdown]
# # Challange
# 1-Plot the number of medals achieved by the Chinese team(both men and women) in Beijing 2008 by both matplotlib and seaborn
# 2- how can you use colormaps to give data more meaning
# 3- Plot the number of gold, silver, and bronze medals for each gender
# 4- How can you give the data more meaning? Is ther anything else you can change to male it more intuitive?

# %%
mw=oo[(oo.NOC=='CHN') & (oo.Edition==2008)]
mw.Gender.value_counts().plot(kind='bar');

# %%
sns.countplot(x='Gender', data =mw);

# %%
sns.countplot(x='Gender', data =oo,palette='bwr');

# %%
sns.countplot(x='Medal' ,data=mw,hue='Gender');

# %%
sns.countplot(x='Medal' ,data=mw,hue='Gender' ,palette='bwr');

# %%
sns.countplot(x='Medal' ,data=mw,hue='Gender' ,palette='bwr' ,order=['Gold','Silver','Bronze']);

# %% [markdown]
# # CHAPTER 7 : INDEXING

# %%
oo.index
# Out:
# RangeIndex(start=0, stop=29216, step=1)

# %%
type(oo.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oo.index[100]
# Out:
# 100

# %%
oo.index[100]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-e4026273403d> in <module>
# ----> 1 oo.index[100]=5
#
# c:\users\habil\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4275     @final
#    4276     def __setitem__(self, key, value):
# -> 4277         raise TypeError("Index does not support mutable operations")
#    4278
#    4279     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete', inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace=True)

# %%
ath = oo.set_index('Athlete')
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath2 = oo.set_index(['Edition','Athlete'])

# %%
ath2.head()
# Out:
#                               City     Sport Discipline  NOC Gender  \
# Edition Athlete
# 1896    HAJOS, Alfred       Athens  Aquatics   Swimming  HUN    Men
#         HERSCHMANN, Otto    Athens  Aquatics   Swimming  AUT    Men
#         DRIVAS, Dimitrios   Athens  Aquatics   Swimming  GRE    Men
#         MALOKINIS, Ioannis  Athens  Aquatics   Swimming  GRE    Men
#         CHASAPIS, Spiridon  Athens  Aquatics   Swimming  GRE    Men
#
#                                                  Event Event_gender   Medal
# Edition Athlete
# 1896    HAJOS, Alfred                   100m freestyle            M    Gold
#         HERSCHMANN, Otto                100m freestyle            M  Silver
#         DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
#         MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
#         CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.reset_index(inplace=True)

# %%
ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath.set_index('Athlete', inplace=True)

# %%
ath.sort_index(inplace=True)
ath.head()
# Out:
#                              City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
#
#                          Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar                Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian       Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian       Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes    Men   team competition            M    Gold

# %%
ath.sort_index(inplace=True, ascending=False)

# %%
ath
# Out:
#                               City  Edition       Sport   Discipline  NOC  \
# Athlete
# ÖSTRAND, Per-Olof         Helsinki     1952    Aquatics     Swimming  SWE
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ÖSTMO, Ole                   Paris     1900    Shooting     Shooting  NOR
# ...                            ...      ...         ...          ...  ...
# AALTONEN, Paavo Johannes    London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes  Helsinki     1952  Gymnastics  Artistic G.  FIN
# AALTONEN, Arvo Ossian      Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian      Antwerp     1920    Aquatics     Swimming  FIN
# AABYE, Edgar                 Paris     1900  Tug of War   Tug of War  ZZX
#
# ...

# %%
ath.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
ath.iloc[100]
# Out:
# City                 Amsterdam
# Edition                   1928
# Sport                 Aquatics
# Discipline            Swimming
# NOC                        ARG
# Gender                     Men
# Event           400m freestyle
# Event_gender                 M
# Medal                     Gold
# Name: ZORRILLA, Victoriano, dtype: object

# %%
ath.iloc[[1542,2390,6000,15000]]
# Out:
#                         City  Edition          Sport       Discipline  NOC  \
# Athlete
# WECKER, Andreas    Barcelona     1992     Gymnastics      Artistic G.  GER
# VARTOLOMEU, Roman     Munich     1972  Canoe / Kayak  Canoe / Kayak F  ROU
# SHARMAN, Samuel        Paris     1924       Shooting         Shooting  USA
# LAUDET, Jean        Helsinki     1952  Canoe / Kayak  Canoe / Kayak F  FRA
#
#                   Gender                   Event Event_gender   Medal
# Athlete
# WECKER, Andreas      Men                   rings            M  Bronze
# VARTOLOMEU, Roman    Men  K-4 1000m (kayak four)            M  Silver
# SHARMAN, Samuel      Men      clay pigeons, team            M    Gold
# LAUDET, Jean         Men              C-2 10000m            M    Gold

# %%
ath.iloc[1:4]
# Out:
#              City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole  Paris     1900  Shooting   Shooting  NOR    Men
#
#                                     Event Event_gender   Medal
# Athlete
# ÖSTMO, Ole  army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole               free rifle, team            M  Silver
# ÖSTMO, Ole     army rifle, 300m, standing            M  Silver

# %%
oo.Edition.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
oo.Edition.value_counts().head(10)
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# Name: Edition, dtype: int64

# %%
oo.Edition.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
lo=oo[(oo.Edition ==2008)]
lo
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 27174        GALPERIN, Gleb  Beijing     2008   Aquatics           Diving
# 27175      MITCHAM, Matthew  Beijing     2008   Aquatics           Diving
# 27176           ZHOU, Luxin  Beijing     2008   Aquatics           Diving
# 27177             WANG, Xin  Beijing     2008   Aquatics           Diving
# 27178          CHEN, Ruolin  Beijing     2008   Aquatics           Diving
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
noc = pd.read_csv('./Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc[noc.Country != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc.set_index('Int Olympic Committee code',inplace=True)

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008=lo.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# AFG      1
# VEN      1
# CMR      1
# SUD      1
# VIE      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medal_2008']=medal_2008
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
noc[noc.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...

# %% [markdown]
# # Group BY

# %%
oo.groupby(by=['Edition'])

# %%
type(oo.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896,
#                         Athlete    City  Edition          Sport  \
#   0               HAJOS, Alfred  Athens     1896       Aquatics
#   1            HERSCHMANN, Otto  Athens     1896       Aquatics
#   2           DRIVAS, Dimitrios  Athens     1896       Aquatics
#   3          MALOKINIS, Ioannis  Athens     1896       Aquatics
#   4          CHASAPIS, Spiridon  Athens     1896       Aquatics
#   ..                        ...     ...      ...            ...
#   146             JENSEN, Viggo  Athens     1896  Weightlifting
#   147       ELLIOTT, Launceston  Athens     1896  Weightlifting
#   148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
#   149            SCHUMANN, Carl  Athens     1896      Wrestling
#   150          TSITAS, Georgios  Athens     1896      Wrestling
#
#             Discipline  NOC Gender                        Event Event_gender  \
#   0           Swimming  HUN    Men               100m freestyle            M
# ...

# %%
for key, value in oo.groupby('Edition'):
    print(key)
    print(value)
# Out:
# 1896
#                       Athlete    City  Edition          Sport  \
# 0               HAJOS, Alfred  Athens     1896       Aquatics
# 1            HERSCHMANN, Otto  Athens     1896       Aquatics
# 2           DRIVAS, Dimitrios  Athens     1896       Aquatics
# 3          MALOKINIS, Ioannis  Athens     1896       Aquatics
# 4          CHASAPIS, Spiridon  Athens     1896       Aquatics
# ..                        ...     ...      ...            ...
# 146             JENSEN, Viggo  Athens     1896  Weightlifting
# 147       ELLIOTT, Launceston  Athens     1896  Weightlifting
# 148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
# 149            SCHUMANN, Carl  Athens     1896      Wrestling
# 150          TSITAS, Georgios  Athens     1896      Wrestling
#
#           Discipline  NOC Gender                        Event Event_gender  \
# 0           Swimming  HUN    Men               100m freestyle            M
# ...

# %%
type(key)
# Out:
# int

# %%
type(value)
# Out:
# pandas.core.frame.DataFrame

# %%
oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
oo.groupby(['Edition','NOC','Medal']).agg(['max','min','count'])
# Out:
#                                     Athlete                                 \
#                                         max                      min count
# Edition NOC Medal
# 1896    AUS Gold               FLACK, Edwin             FLACK, Edwin     2
#         AUT Bronze            SCHMAL, Adolf            SCHMAL, Adolf     2
#             Gold              SCHMAL, Adolf            NEUMANN, Paul     2
#             Silver         HERSCHMANN, Otto         HERSCHMANN, Otto     1
#         DEN Bronze          NIELSEN, Holger            JENSEN, Viggo     3
# ...                                     ...                      ...   ...
# 2008    UZB Silver           TIGIEV, Soslan        TANGRIEV, Abdullo     2
#         VEN Bronze  CONTRERAS RIVERO, Dalia  CONTRERAS RIVERO, Dalia     1
#         VIE Silver          HOANG, Anh Tuan          HOANG, Anh Tuan     1
#         ZIM Gold           COVENTRY, Kirsty         COVENTRY, Kirsty     1
# ...

# %%
oo.groupby(['Edition','NOC','Medal']).agg(['count'])
# Out:
#                    Athlete  City Sport Discipline Gender Event Event_gender
#                      count count count      count  count count        count
# Edition NOC Medal
# 1896    AUS Gold         2     2     2          2      2     2            2
#         AUT Bronze       2     2     2          2      2     2            2
#             Gold         2     2     2          2      2     2            2
#             Silver       1     1     1          1      1     1            1
#         DEN Bronze       3     3     3          3      3     3            3
# ...                    ...   ...   ...        ...    ...   ...          ...
# 2008    UZB Silver       2     2     2          2      2     2            2
#         VEN Bronze       1     1     1          1      1     1            1
#         VIE Silver       1     1     1          1      1     1            1
#         ZIM Gold         1     1     1          1      1     1            1
# ...

# %%
oo.groupby(['Edition','NOC','Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %%
oo.groupby(['Edition','NOC','Medal']).agg({'Edition':['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %% [markdown]
# # ---------------------------------CROSS tab VS. GROUP BY-----------------------------

# %%
crss=oo[(oo.NOC == "CHN") & (oo.Edition==2008)]
crss
# Out:
#                 Athlete     City  Edition          Sport       Discipline  \
# 27176       ZHOU, Luxin  Beijing     2008       Aquatics           Diving
# 27177         WANG, Xin  Beijing     2008       Aquatics           Diving
# 27178      CHEN, Ruolin  Beijing     2008       Aquatics           Diving
# 27180          QIN, Kai  Beijing     2008       Aquatics           Diving
# 27181         HE, Chong  Beijing     2008       Aquatics           Diving
# ...                 ...      ...      ...            ...              ...
# 29138        LI, Hongli  Beijing     2008  Weightlifting    Weightlifting
# 29140          LU, Yong  Beijing     2008  Weightlifting    Weightlifting
# 29156            XU, Li  Beijing     2008      Wrestling  Wrestling Free.
# 29171        WANG, Jiao  Beijing     2008      Wrestling  Wrestling Free.
# 29204  CHANG, Yongxiang  Beijing     2008      Wrestling  Wrestling Gre-R
#
#        NOC Gender           Event Event_gender   Medal
# ...

# %%
pd.crosstab(index=crss.Gender ,columns=crss.Medal)
# Out:
# Medal   Bronze  Gold  Silver
# Gender
# Men         11    34      11
# Women       46    40      42

# %%
type(pd.crosstab(index=crss.Gender ,columns=crss.Medal))
# Out:
# pandas.core.frame.DataFrame

# %%
list(crss.groupby(['Gender','Medal']))
# Out:
# [(('Men', 'Bronze'),
#                 Athlete     City  Edition         Sport    Discipline  NOC  \
#   27180        QIN, Kai  Beijing     2008      Aquatics        Diving  CHN
#   27527      JIANG, Lin  Beijing     2008       Archery       Archery  CHN
#   27528     LI, Wenquan  Beijing     2008       Archery       Archery  CHN
#   27529   XUE, Hai Feng  Beijing     2008       Archery       Archery  CHN
#   27724      HE, Hanbin  Beijing     2008     Badminton     Badminton  CHN
#   27740       CHEN, Jin  Beijing     2008     Badminton     Badminton  CHN
#   27918  HANATI, Silamu  Beijing     2008        Boxing        Boxing  CHN
#   28397      DONG, Dong  Beijing     2008    Gymnastics    Trampoline  CHN
#   28876     HU, Binyuan  Beijing     2008      Shooting      Shooting  CHN
#   28936     WANG, Liqin  Beijing     2008  Table Tennis  Table Tennis  CHN
#   28989        ZHU, Guo  Beijing     2008     Taekwondo     Taekwondo  CHN
#
# ...

# %%
test=crss.groupby(['Gender','Medal']).size()
test
# Out:
# Gender  Medal
# Men     Bronze    11
#         Gold      34
#         Silver    11
# Women   Bronze    46
#         Gold      40
#         Silver    42
# dtype: int64

# %%
type(crss.groupby(['Gender','Medal']).size())
# Out:
# pandas.core.series.Series

# %%
test.index
# Out:
# MultiIndex([(  'Men', 'Bronze'),
#             (  'Men',   'Gold'),
#             (  'Men', 'Silver'),
#             ('Women', 'Bronze'),
#             ('Women',   'Gold'),
#             ('Women', 'Silver')],
#            names=['Gender', 'Medal'])

# %% [markdown]
# # --------------------------------------------The End------------------------------------------

# %%
oo.loc[oo.Athlete == 'LEWIS, Carl']
# Out:
#            Athlete         City  Edition      Sport Discipline  NOC Gender  \
# 16794  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 16813  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 16845  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 16927  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 18284  LEWIS, Carl        Seoul     1988  Athletics  Athletics  USA    Men
# 18303  LEWIS, Carl        Seoul     1988  Athletics  Athletics  USA    Men
# 18417  LEWIS, Carl        Seoul     1988  Athletics  Athletics  USA    Men
# 19909  LEWIS, Carl    Barcelona     1992  Athletics  Athletics  USA    Men
# 20004  LEWIS, Carl    Barcelona     1992  Athletics  Athletics  USA    Men
# 21742  LEWIS, Carl      Atlanta     1996  Athletics  Athletics  USA    Men
#
#               Event Event_gender   Medal
# 16794          100m            M    Gold
# 16813          200m            M    Gold
# ...

# %%
result =oo.loc[oo.Athlete == 'LEWIS, Carl'].groupby('Athlete')
for key,value in result:
    print(key)
    print(value)
# Out:
# LEWIS, Carl
#            Athlete         City  Edition      Sport Discipline  NOC Gender  \
# 16794  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 16813  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 16845  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 16927  LEWIS, Carl  Los Angeles     1984  Athletics  Athletics  USA    Men
# 18284  LEWIS, Carl        Seoul     1988  Athletics  Athletics  USA    Men
# 18303  LEWIS, Carl        Seoul     1988  Athletics  Athletics  USA    Men
# 18417  LEWIS, Carl        Seoul     1988  Athletics  Athletics  USA    Men
# 19909  LEWIS, Carl    Barcelona     1992  Athletics  Athletics  USA    Men
# 20004  LEWIS, Carl    Barcelona     1992  Athletics  Athletics  USA    Men
# 21742  LEWIS, Carl      Atlanta     1996  Athletics  Athletics  USA    Men
#
#               Event Event_gender   Medal
# 16794          100m            M    Gold
# 16813          200m            M    Gold
# ...

# %%
result.agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
oo.groupby('Edition').agg({'Medal':['count']}).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Edition'>

# %%
oo.groupby('Edition').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Edition'>

# %%
oo.groupby('NOC').agg({'Edition':['min','max'],'Medal':['count']})
# Out:
#     Edition       Medal
#         min   max count
# NOC
# AFG    2008  2008     1
# AHO    1988  1988     1
# ALG    1984  2008    14
# ANZ    1908  1912    29
# ARG    1924  2008   239
# ..      ...   ...   ...
# VIE    2000  2008     2
# YUG    1924  2000   435
# ZAM    1984  1996     2
# ZIM    1980  2008    23
# ZZX    1896  1904    48
#
# [138 rows x 3 columns]

# %%
hbl=oo[(oo.Edition ==2008) & ((oo.Event == '100m') |(oo.Event == '200m'))]
hbl
# Out:
#                         Athlete     City  Edition      Sport Discipline  NOC  \
# 27551               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27552               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27553         THOMPSON, Richard  Beijing     2008  Athletics  Athletics  TRI
# 27554        FRASER, Shelly-ann  Beijing     2008  Athletics  Athletics  JAM
# 27555          SIMPSON, Sherone  Beijing     2008  Athletics  Athletics  JAM
# 27556           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27569               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27570               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27571           CRAWFORD, Shawn  Beijing     2008  Athletics  Athletics  USA
# 27572           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27573  CAMPBELL-BROWN, Veronica  Beijing     2008  Athletics  Athletics  JAM
# ...

# %%
gn=hbl.groupby(['NOC','Gender','Discipline','Event']).size()
gn
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
gn.unstack('Discipline','Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m           1
#            200m           1
#     Women  100m           3
#            200m           2
# TRI Men    100m           1
# USA Men    100m           1
#            200m           2
#     Women  200m           1

# %%
# Out:
#               Athlete    City  Edition     Sport
# 0       HAJOS, Alfred  Athens     1896  Aquatics
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics

# %% [markdown]
# # --------------------------------DATA Visualization---------------------------------------------
# ## 1- Heatmaps

# %%
lo=oo[oo.Edition==2008]
lo
# Out:
#                     Athlete     City  Edition      Sport       Discipline  \
# 27174        GALPERIN, Gleb  Beijing     2008   Aquatics           Diving
# 27175      MITCHAM, Matthew  Beijing     2008   Aquatics           Diving
# 27176           ZHOU, Luxin  Beijing     2008   Aquatics           Diving
# 27177             WANG, Xin  Beijing     2008   Aquatics           Diving
# 27178          CHEN, Ruolin  Beijing     2008   Aquatics           Diving
# ...                     ...      ...      ...        ...              ...
# 29211        ENGLICH, Mirko  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213       PATRIKEEV, Yuri  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214         LOPEZ, Mijain  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215        BAROEV, Khasan  Beijing     2008  Wrestling  Wrestling Gre-R
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
lo2= lo.groupby(['NOC','Medal']).size()
lo2
# Out:
# NOC  Medal
# AFG  Bronze     1
# ALG  Bronze     1
#      Silver     1
# ARG  Bronze    31
#      Gold      20
#                ..
# UZB  Silver     2
# VEN  Bronze     1
# VIE  Silver     1
# ZIM  Gold       1
#      Silver     3
# Length: 188, dtype: int64

# %%
lo2.unstack('Medal',fill_value=0)
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# AFG         1     0       0
# ALG         1     0       1
# ARG        31    20       0
# ARM         6     0       0
# AUS        76    31      42
# ..        ...   ...     ...
# USA        81   125     109
# UZB         3     1       2
# VEN         1     0       0
# VIE         0     0       1
# ZIM         0     1       3
#
# [86 rows x 3 columns]

# %%
ls=_.sort_values(['Gold','Silver',"Bronze"], ascending=False)[['Gold','Silver','Bronze']]
ls
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
ls.transpose()
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN  ...  VIE  ARM  TPE  \
# Medal                                                     ...
# Gold    125   74   43   42   41   40   31   31   25   23  ...    0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11  ...    1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17  ...    0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
plt.figure(figsize=(16,5))
sns.heatmap(ls.transpose())
# Out:
# <AxesSubplot:xlabel='NOC', ylabel='Medal'>

# %%
g= oo.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)

g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
from matplotlib.colors import ListedColormap

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
gsb=['#dbb40c','#c5c9c7','#a87900']
sns.palplot(sns.color_palette(gsb))

# %%
my_gsb=ListedColormap(sns.color_palette(gsb))

# %%
g= oo.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)

g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head().plot(kind='bar',colormap=my_gsb)
# Out:
# <AxesSubplot:xlabel='Athlete'>
